# %%
seq=[1,2,3,4,5]

# %%
for num in seq:
    print(num)
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
for num in seq:
    print('hello')
# Out:
# hello
# hello
# hello
# hello
# hello

# %%
 i=1

# %%
while i<5:
    print('the number is {}'.format(i))
# Out:
# the number is 1
# the number is 1
# the number is 1
# the number is 1
# the number is 1
# the number is 1
# the number is 1
# the number is 1
# the number is 1
# the number is 1
# the number is 1
# the number is 1
# the number is 1
# the number is 1
# the number is 1
# the number is 1
# the number is 1
# the number is 1
# the number is 1
# the number is 1
# the number is 1
# the number is 1
# the number is 1
# the number is 1
# the number is 1
# the number is 1
# the number is 1
# the number is 1
# the number is 1
# the number is 1
# the number is 1
# the number is 1
# the number is 1
# the number is 1
# the number is 1
# the number is 1
# the number is 1
# the number is 1
# the number is 1
# the number is 1
# the number is 1
# the number is 1
# the number is 1
# the number is 1
# the number is 1
# the number is 1
# the number is 1
# the number is 1
# the number is 1
# the number is 1
# the number is 1
# the number is 1
# the number is 1
# the number is 1
# the number is 1
# ...

# %%
 i=1
while i<5:
    print('the number is{}'.format(i))
    i=i+1
# Out:
# the number is1
# the number is2
# the number is3
# the number is4

# %%
x=[1,2,3,4,5]

# %%
out=[]

# %%
for x in range(0,5):
     print(x)
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
for num in x:
    out.append(num *2)

# %%
print(out)
# Out:
# [2, 4, 6, 8, 10, 1, 4, 9, 16, 25, 2, 4, 6, 8, 10, 2, 4, 6, 8, 10]
