# %%
import numpy as np
import re
import pandas as pd
import scipy.stats as stats
import matplotlib.pyplot as plt
import seaborn as sns
from math import factorial as f
from sklearn. linear_model import LogisticRegression
from sklearn.naive_bayes import GaussianNB,BernoulliNB,MultinomialNB
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score
from sklearn.metrics import classification_report


from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import MultinomialNB
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.metrics import r2_score, mean_absolute_error, mean_squared_error
from matplotlib.font_manager import FontProperties
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor, AdaBoostRegressor,StackingRegressor
from sklearn.preprocessing import MinMaxScaler
from sklearn.linear_model import LinearRegression

# %%
# %pip install -U scikit-learn
# Out:
# Requirement already satisfied: scikit-learn in c:\users\thenu\anaconda\lib\site-packages (1.0.2)Note: you may need to restart the kernel to use updated packages.
#
# Collecting scikit-learn
#   Downloading scikit_learn-1.2.2-cp39-cp39-win_amd64.whl (8.4 MB)
#      ---------------------------------------- 8.4/8.4 MB 3.7 MB/s eta 0:00:00
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\thenu\anaconda\lib\site-packages (from scikit-learn) (2.2.0)
# Requirement already satisfied: numpy>=1.17.3 in c:\users\thenu\anaconda\lib\site-packages (from scikit-learn) (1.21.5)
# Requirement already satisfied: scipy>=1.3.2 in c:\users\thenu\anaconda\lib\site-packages (from scikit-learn) (1.9.1)
# Collecting joblib>=1.1.1
#   Using cached joblib-1.2.0-py3-none-any.whl (297 kB)
# Installing collected packages: joblib, scikit-learn
#   Attempting uninstall: joblib
#     Found existing installation: joblib 1.1.0
#     Uninstalling joblib-1.1.0:
#       Successfully uninstalled joblib-1.1.0
#   Attempting uninstall: scikit-learn
#     Found existing installation: scikit-learn 1.0.2
#     Uninstalling scikit-learn-1.0.2:
#       Successfully uninstalled scikit-learn-1.0.2
# Successfully installed joblib-1.2.0 scikit-learn-1.2.2

# %%
df = pd.read_csv('C://pro10//Apps_data.csv')

# %%
df.info
# Out:
# <bound method DataFrame.info of                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                             Parkinson Exercices FR              MEDICAL
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
#        Rating Reviews                Size     Installs  Type Price  \
# 0         4.1     159                 19M      10,000+  Free     0
# 1         3.9     967                 14M     500,000+  Free     0
# 2         4.7   87510                8.7M   5,000,000+  Free     0
# 3         4.5  215644                 25M  50,000,000+  Free     0
# 4         4.3     967                2.8M     100,000+  Free     0
# ...       ...     ...                 ...          ...   ...   ...
# 10836     4.5      38                 53M       5,000+  Free     0
# 10837     5.0       4                3.6M         100+  Free     0
# 10838     NaN       3                9.5M       1,000+  Free     0
# 10839     4.5     114  Varies with device       1,000+  Free     0
# 10840     4.5  398307                 19M  10,000,000+  Free     0
#
#       Content Rating                     Genres      Last Updated  \
# 0           Everyone               Art & Design   January 7, 2018
# 1           Everyone  Art & Design;Pretend Play  January 15, 2018
# 2           Everyone               Art & Design    August 1, 2018
# 3               Teen               Art & Design      June 8, 2018
# 4           Everyone    Art & Design;Creativity     June 20, 2018
# ...              ...                        ...               ...
# 10836       Everyone                  Education     July 25, 2017
# 10837       Everyone                  Education      July 6, 2018
# 10838       Everyone                    Medical  January 20, 2017
# 10839     Mature 17+          Books & Reference  January 19, 2015
# 10840       Everyone                  Lifestyle     July 25, 2018
#
#               Current Ver         Android Ver
# 0                   1.0.0        4.0.3 and up
# 1                   2.0.0        4.0.3 and up
# 2                   1.2.4        4.0.3 and up
# 3      Varies with device          4.2 and up
# 4                     1.1          4.4 and up
# ...                   ...                 ...
# 10836                1.48          4.1 and up
# 10837                 1.0          4.1 and up
# 10838                 1.0          2.2 and up
# 10839  Varies with device  Varies with device
# 10840  Varies with device  Varies with device
#
# [10841 rows x 13 columns]>

# %%
df.dtypes
# Out:
# App                object
# Category           object
# Rating            float64
# Reviews            object
# Size               object
# Installs           object
# Type               object
# Price              object
# Content Rating     object
# Genres             object
# Last Updated       object
# Current Ver        object
# Android Ver        object
# dtype: object

# %%
df['Category']
# Out:
# 0             ART_AND_DESIGN
# 1             ART_AND_DESIGN
# 2             ART_AND_DESIGN
# 3             ART_AND_DESIGN
# 4             ART_AND_DESIGN
#                 ...
# 10836                 FAMILY
# 10837                 FAMILY
# 10838                MEDICAL
# 10839    BOOKS_AND_REFERENCE
# 10840              LIFESTYLE
# Name: Category, Length: 10841, dtype: object

# %%
df.shape
# Out:
# (10841, 13)

# %%
df
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                             Parkinson Exercices FR              MEDICAL
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
#        Rating Reviews                Size     Installs  Type Price  \
# 0         4.1     159                 19M      10,000+  Free     0
# 1         3.9     967                 14M     500,000+  Free     0
# 2         4.7   87510                8.7M   5,000,000+  Free     0
# 3         4.5  215644                 25M  50,000,000+  Free     0
# 4         4.3     967                2.8M     100,000+  Free     0
# ...       ...     ...                 ...          ...   ...   ...
# 10836     4.5      38                 53M       5,000+  Free     0
# 10837     5.0       4                3.6M         100+  Free     0
# 10838     NaN       3                9.5M       1,000+  Free     0
# 10839     4.5     114  Varies with device       1,000+  Free     0
# 10840     4.5  398307                 19M  10,000,000+  Free     0
#
#       Content Rating                     Genres      Last Updated  \
# 0           Everyone               Art & Design   January 7, 2018
# 1           Everyone  Art & Design;Pretend Play  January 15, 2018
# 2           Everyone               Art & Design    August 1, 2018
# 3               Teen               Art & Design      June 8, 2018
# 4           Everyone    Art & Design;Creativity     June 20, 2018
# ...              ...                        ...               ...
# 10836       Everyone                  Education     July 25, 2017
# 10837       Everyone                  Education      July 6, 2018
# 10838       Everyone                    Medical  January 20, 2017
# 10839     Mature 17+          Books & Reference  January 19, 2015
# 10840       Everyone                  Lifestyle     July 25, 2018
#
#               Current Ver         Android Ver
# 0                   1.0.0        4.0.3 and up
# 1                   2.0.0        4.0.3 and up
# 2                   1.2.4        4.0.3 and up
# 3      Varies with device          4.2 and up
# 4                     1.1          4.4 and up
# ...                   ...                 ...
# 10836                1.48          4.1 and up
# 10837                 1.0          4.1 and up
# 10838                 1.0          2.2 and up
# 10839  Varies with device  Varies with device
# 10840  Varies with device  Varies with device
#
# [10841 rows x 13 columns]

# %%
Category_value=df['Category'].unique

# %%
Category_value
# Out:
# <bound method Series.unique of 0             ART_AND_DESIGN
# 1             ART_AND_DESIGN
# 2             ART_AND_DESIGN
# 3             ART_AND_DESIGN
# 4             ART_AND_DESIGN
#                 ...
# 10836                 FAMILY
# 10837                 FAMILY
# 10838                MEDICAL
# 10839    BOOKS_AND_REFERENCE
# 10840              LIFESTYLE
# Name: Category, Length: 10841, dtype: object>

# %%
df.Category.value_counts()
# Out:
# FAMILY                 1972
# GAME                   1144
# TOOLS                   843
# MEDICAL                 463
# BUSINESS                460
# PRODUCTIVITY            424
# PERSONALIZATION         392
# COMMUNICATION           387
# SPORTS                  384
# LIFESTYLE               382
# FINANCE                 366
# HEALTH_AND_FITNESS      341
# PHOTOGRAPHY             335
# SOCIAL                  295
# NEWS_AND_MAGAZINES      283
# SHOPPING                260
# TRAVEL_AND_LOCAL        258
# DATING                  234
# BOOKS_AND_REFERENCE     231
# VIDEO_PLAYERS           175
# EDUCATION               156
# ENTERTAINMENT           149
# MAPS_AND_NAVIGATION     137
# FOOD_AND_DRINK          127
# HOUSE_AND_HOME           88
# AUTO_AND_VEHICLES        85
# LIBRARIES_AND_DEMO       85
# WEATHER                  82
# ART_AND_DESIGN           65
# EVENTS                   64
# COMICS                   60
# PARENTING                60
# BEAUTY                   53
# 1.9                       1
# Name: Category, dtype: int64

# %%
df1=df[-((df["Android Ver"].isnull()) & (df["Category"]=='1.9'))]

# %%
df1.shape
# Out:
# (10840, 13)

# %%
df1.Category.value_counts()
# Out:
# FAMILY                 1972
# GAME                   1144
# TOOLS                   843
# MEDICAL                 463
# BUSINESS                460
# PRODUCTIVITY            424
# PERSONALIZATION         392
# COMMUNICATION           387
# SPORTS                  384
# LIFESTYLE               382
# FINANCE                 366
# HEALTH_AND_FITNESS      341
# PHOTOGRAPHY             335
# SOCIAL                  295
# NEWS_AND_MAGAZINES      283
# SHOPPING                260
# TRAVEL_AND_LOCAL        258
# DATING                  234
# BOOKS_AND_REFERENCE     231
# VIDEO_PLAYERS           175
# EDUCATION               156
# ENTERTAINMENT           149
# MAPS_AND_NAVIGATION     137
# FOOD_AND_DRINK          127
# HOUSE_AND_HOME           88
# AUTO_AND_VEHICLES        85
# LIBRARIES_AND_DEMO       85
# WEATHER                  82
# ART_AND_DESIGN           65
# EVENTS                   64
# PARENTING                60
# COMICS                   60
# BEAUTY                   53
# Name: Category, dtype: int64

# %%
df1.describe().transpose
# Out:
# <bound method DataFrame.transpose of             Rating
# count  9366.000000
# mean      4.191757
# std       0.515219
# min       1.000000
# 25%       4.000000
# 50%       4.300000
# 75%       4.500000
# max       5.000000>

# %%
df1.isnull().sum()
# Out:
# App                  0
# Category             0
# Rating            1474
# Reviews              0
# Size                 0
# Installs             0
# Type                 1
# Price                0
# Content Rating       0
# Genres               0
# Last Updated         0
# Current Ver          8
# Android Ver          2
# dtype: int64

# %%
mean_value=df1['Rating'].mean()
df1["Rating"].fillna(mean_value, inplace = True)
df1["Type"].fillna( method ='ffill', inplace = True)
df1["Content Rating"].fillna( method ='ffill', inplace = True)
df1["Android Ver"].fillna( method ='ffill', inplace = True)
df1["Current Ver"].fillna( method ='ffill', inplace = True)
df1["Size"].fillna(method='ffill',inplace=True)
# Out:
# C:\Users\thenu\AppData\Local\Temp\ipykernel_38468\2182829470.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1["Rating"].fillna(mean_value, inplace = True)
# C:\Users\thenu\AppData\Local\Temp\ipykernel_38468\2182829470.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1["Type"].fillna( method ='ffill', inplace = True)
# C:\Users\thenu\AppData\Local\Temp\ipykernel_38468\2182829470.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1["Content Rating"].fillna( method ='ffill', inplace = True)
# C:\Users\thenu\AppData\Local\Temp\ipykernel_38468\2182829470.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1["Android Ver"].fillna( method ='ffill', inplace = True)
# C:\Users\thenu\AppData\Local\Temp\ipykernel_38468\2182829470.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1["Current Ver"].fillna( method ='ffill', inplace = True)
# C:\Users\thenu\AppData\Local\Temp\ipykernel_38468\2182829470.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1["Size"].fillna(method='ffill',inplace=True)

# %%
df1['Rating']
# Out:
# 0        4.1
# 1        3.9
# 2        4.7
# 3        4.5
# 4        4.3
#         ...
# 10836    4.5
# 10837    5.0
# 10838    NaN
# 10839    4.5
# 10840    4.5
# Name: Rating, Length: 10840, dtype: float64

# %%
df1.isnull().sum()
# Out:
# App               0
# Category          0
# Rating            0
# Reviews           0
# Size              0
# Installs          0
# Type              0
# Price             0
# Content Rating    0
# Genres            0
# Last Updated      0
# Current Ver       0
# Android Ver       0
# dtype: int64

# %%
def check_duplicate(df1):
    duplicate=df1[df1.duplicated()]
    return duplicate

duplicate=check_duplicate(df1)
duplicate
# Out:
#                                                    App      Category  Rating  \
# 229                       Quick PDF Scanner + OCR FREE      BUSINESS     4.2
# 236                                                Box      BUSINESS     4.2
# 239                                 Google My Business      BUSINESS     4.4
# 256                                ZOOM Cloud Meetings      BUSINESS     4.4
# 261                          join.me - Simple Meetings      BUSINESS     4.0
# ...                                                ...           ...     ...
# 8643                    Wunderlist: To-Do List & Tasks  PRODUCTIVITY     4.6
# 8654   TickTick: To Do List with Reminder, Day Planner  PRODUCTIVITY     4.6
# 8658                           ColorNote Notepad Notes  PRODUCTIVITY     4.6
# 10049        Airway Ex - Intubate. Anesthetize. Train.       MEDICAL     4.3
# 10768                                             AAFP       MEDICAL     3.8
#
#        Reviews                Size      Installs  Type Price Content Rating  \
# 229      80805  Varies with device    5,000,000+  Free     0       Everyone
# 236     159872  Varies with device   10,000,000+  Free     0       Everyone
# 239      70991  Varies with device    5,000,000+  Free     0       Everyone
# 256      31614                 37M   10,000,000+  Free     0       Everyone
# 261       6989  Varies with device    1,000,000+  Free     0       Everyone
# ...        ...                 ...           ...   ...   ...            ...
# 8643    404610  Varies with device   10,000,000+  Free     0       Everyone
# 8654     25370  Varies with device    1,000,000+  Free     0       Everyone
# 8658   2401017  Varies with device  100,000,000+  Free     0       Everyone
# 10049      123                 86M       10,000+  Free     0       Everyone
# 10768       63                 24M       10,000+  Free     0       Everyone
#
#              Genres       Last Updated         Current Ver         Android Ver
# 229        Business  February 26, 2018  Varies with device        4.0.3 and up
# 236        Business      July 31, 2018  Varies with device  Varies with device
# 239        Business      July 24, 2018    2.19.0.204537701          4.4 and up
# 256        Business      July 20, 2018      4.1.28165.0716          4.0 and up
# 261        Business      July 16, 2018           4.3.0.508          4.4 and up
# ...             ...                ...                 ...                 ...
# 8643   Productivity      April 6, 2018  Varies with device  Varies with device
# 8654   Productivity     August 6, 2018  Varies with device  Varies with device
# 8658   Productivity      June 27, 2018  Varies with device  Varies with device
# 10049       Medical       June 1, 2018              0.6.88          5.0 and up
# 10768       Medical      June 22, 2018               2.3.1          5.0 and up
#
# [483 rows x 13 columns]

# %%
def check_missing_values(df1):


    print("percentage of missing data of dataframe \n",df1.isnull().sum()/len(df1)*100)

# %%
df1.dtypes
# Out:
# App                object
# Category           object
# Rating            float64
# Reviews            object
# Size               object
# Installs           object
# Type               object
# Price              object
# Content Rating     object
# Genres             object
# Last Updated       object
# Current Ver        object
# Android Ver        object
# dtype: object

# %%
rate=0
def categorise(row):  
    if rate > 3.5: 
        return 'high'
    elif rate <= 3.5 :
        return 'low'

# %%
df['Rating']
# Out:
# 0        4.1
# 1        3.9
# 2        4.7
# 3        4.5
# 4        4.3
#         ...
# 10836    4.5
# 10837    5.0
# 10838    NaN
# 10839    4.5
# 10840    4.5
# Name: Rating, Length: 10841, dtype: float64

# %%
df['Rating']=[i for i in map(lambda x: 'high' if x >3.5 else 'low', df['Rating'])]

# %%
df
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                             Parkinson Exercices FR              MEDICAL
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
#       Rating Reviews                Size     Installs  Type Price  \
# 0       high     159                 19M      10,000+  Free     0
# 1       high     967                 14M     500,000+  Free     0
# 2       high   87510                8.7M   5,000,000+  Free     0
# 3       high  215644                 25M  50,000,000+  Free     0
# 4       high     967                2.8M     100,000+  Free     0
# ...      ...     ...                 ...          ...   ...   ...
# 10836   high      38                 53M       5,000+  Free     0
# 10837   high       4                3.6M         100+  Free     0
# 10838    low       3                9.5M       1,000+  Free     0
# 10839   high     114  Varies with device       1,000+  Free     0
# 10840   high  398307                 19M  10,000,000+  Free     0
#
#       Content Rating                     Genres      Last Updated  \
# 0           Everyone               Art & Design   January 7, 2018
# 1           Everyone  Art & Design;Pretend Play  January 15, 2018
# 2           Everyone               Art & Design    August 1, 2018
# 3               Teen               Art & Design      June 8, 2018
# 4           Everyone    Art & Design;Creativity     June 20, 2018
# ...              ...                        ...               ...
# 10836       Everyone                  Education     July 25, 2017
# 10837       Everyone                  Education      July 6, 2018
# 10838       Everyone                    Medical  January 20, 2017
# 10839     Mature 17+          Books & Reference  January 19, 2015
# 10840       Everyone                  Lifestyle     July 25, 2018
#
#               Current Ver         Android Ver
# 0                   1.0.0        4.0.3 and up
# 1                   2.0.0        4.0.3 and up
# 2                   1.2.4        4.0.3 and up
# 3      Varies with device          4.2 and up
# 4                     1.1          4.4 and up
# ...                   ...                 ...
# 10836                1.48          4.1 and up
# 10837                 1.0          4.1 and up
# 10838                 1.0          2.2 and up
# 10839  Varies with device  Varies with device
# 10840  Varies with device  Varies with device
#
# [10841 rows x 13 columns]

# %%
df1['Rating']=[i for i in map(lambda x: 'high' if x >3.5 else 'low', df1['Rating'])]
# Out:
# <ipython-input-114-695d69334af6>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['Rating']=[i for i in map(lambda x: 'high' if x >3.5 else 'low', df1['Rating'])]

# %%
df1.isnull().sum()
# Out:
# App               0
# Category          0
# Rating            0
# Reviews           0
# Size              0
# Installs          0
# Type              0
# Price             0
# Content Rating    0
# Genres            0
# Last Updated      0
# Current Ver       0
# Android Ver       0
# dtype: int64

# %%
df1.rename(columns = {'Rating':'Rating_category'}, inplace = True)
# Out:
# C:\Users\thenu\AppData\Local\Temp\ipykernel_38468\1246521445.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1.rename(columns = {'Rating':'Rating_category'}, inplace = True)

# %%
df1
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                             Parkinson Exercices FR              MEDICAL
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
#        Rating_category Reviews                Size     Installs  Type Price  \
# 0             4.100000     159                 19M      10,000+  Free     0
# 1             3.900000     967                 14M     500,000+  Free     0
# 2             4.700000   87510                8.7M   5,000,000+  Free     0
# 3             4.500000  215644                 25M  50,000,000+  Free     0
# 4             4.300000     967                2.8M     100,000+  Free     0
# ...                ...     ...                 ...          ...   ...   ...
# 10836         4.500000      38                 53M       5,000+  Free     0
# 10837         5.000000       4                3.6M         100+  Free     0
# 10838         4.191757       3                9.5M       1,000+  Free     0
# 10839         4.500000     114  Varies with device       1,000+  Free     0
# 10840         4.500000  398307                 19M  10,000,000+  Free     0
#
#       Content Rating                     Genres      Last Updated  \
# 0           Everyone               Art & Design   January 7, 2018
# 1           Everyone  Art & Design;Pretend Play  January 15, 2018
# 2           Everyone               Art & Design    August 1, 2018
# 3               Teen               Art & Design      June 8, 2018
# 4           Everyone    Art & Design;Creativity     June 20, 2018
# ...              ...                        ...               ...
# 10836       Everyone                  Education     July 25, 2017
# 10837       Everyone                  Education      July 6, 2018
# 10838       Everyone                    Medical  January 20, 2017
# 10839     Mature 17+          Books & Reference  January 19, 2015
# 10840       Everyone                  Lifestyle     July 25, 2018
#
#               Current Ver         Android Ver
# 0                   1.0.0        4.0.3 and up
# 1                   2.0.0        4.0.3 and up
# 2                   1.2.4        4.0.3 and up
# 3      Varies with device          4.2 and up
# 4                     1.1          4.4 and up
# ...                   ...                 ...
# 10836                1.48          4.1 and up
# 10837                 1.0          4.1 and up
# 10838                 1.0          2.2 and up
# 10839  Varies with device  Varies with device
# 10840  Varies with device  Varies with device
#
# [10840 rows x 13 columns]

# %%
#Check the distribution of the newly created column 'Rating_category' and comment on the distribution

# %%
df1.Reviews.astype('float')
# Out:
# 0           159.0
# 1           967.0
# 2         87510.0
# 3        215644.0
# 4           967.0
#            ...
# 10836        38.0
# 10837         4.0
# 10838         3.0
# 10839       114.0
# 10840    398307.0
# Name: Reviews, Length: 10840, dtype: float64

# %%
df1.dtypes
# Out:
# App                object
# Category           object
# Rating_category    object
# Reviews            object
# Size               object
# Installs           object
# Type               object
# Price              object
# Content Rating     object
# Genres             object
# Last Updated       object
# Current Ver        object
# Android Ver        object
# dtype: object

# %%
df1.isnull().sum()
# Out:
# App                0
# Category           0
# Rating_category    0
# Reviews            0
# Size               0
# Installs           0
# Type               0
# Price              0
# Content Rating     0
# Genres             0
# Last Updated       0
# Current Ver        0
# Android Ver        0
# dtype: int64

# %%
sns.set_style('whitegrid')
plt.figure(figsize=(16,8))
plt.title('Number of apps on the basis of category')
sns.countplot(x='Category',data = df1)
plt.xticks(rotation=90)
plt.show()

# %%
rating_low_4 = len(df1[df1['Rating_category']== 'low'])/len(df1)*100

# %%
rating_low_4
# Out:
# 8.265682656826568

# %%
rating_greater_4 = len(df1[df1['Rating_category']== 'high'])/len(df1)*100

# %%
rating_greater_4
# Out:
# 91.73431734317343

# %%
#Convert the column "Reviews" to numeric datatype and check the presence of outliers in the column and
#handle the outliers using transformation approach

# %%
df1['Reviews']=df1.Reviews.astype('int64')
# Out:
# <ipython-input-128-500d051240f4>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['Reviews']=df1.Reviews.astype('int64')

# %%
df1.dtypes
# Out:
# App                object
# Category           object
# Rating_category    object
# Reviews             int64
# Size               object
# Installs           object
# Type               object
# Price              object
# Content Rating     object
# Genres             object
# Last Updated       object
# Current Ver        object
# Android Ver        object
# dtype: object

# %%
def value_to_float(x):

    if type(x) == float or type(x) == int:
        return x
    if x ==" ":
        return 'none'  
    if 'K' in x:
        if len(x) > 1:
            return float(x.replace('K', '')) * 1000
        return 1000.0
    if 'M' in x:
        if len(x) > 1:
            return float(x.replace('M', '')) * 1000000
        return 1000000.0
    if 'B' in x:
        return float(x.replace('B', '')) * 1000000000

# %%
df1
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                             Parkinson Exercices FR              MEDICAL
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
#        Rating_category Reviews                Size     Installs  Type Price  \
# 0             4.100000     159                 19M      10,000+  Free     0
# 1             3.900000     967                 14M     500,000+  Free     0
# 2             4.700000   87510                8.7M   5,000,000+  Free     0
# 3             4.500000  215644                 25M  50,000,000+  Free     0
# 4             4.300000     967                2.8M     100,000+  Free     0
# ...                ...     ...                 ...          ...   ...   ...
# 10836         4.500000      38                 53M       5,000+  Free     0
# 10837         5.000000       4                3.6M         100+  Free     0
# 10838         4.191757       3                9.5M       1,000+  Free     0
# 10839         4.500000     114  Varies with device       1,000+  Free     0
# 10840         4.500000  398307                 19M  10,000,000+  Free     0
#
#       Content Rating                     Genres      Last Updated  \
# 0           Everyone               Art & Design   January 7, 2018
# 1           Everyone  Art & Design;Pretend Play  January 15, 2018
# 2           Everyone               Art & Design    August 1, 2018
# 3               Teen               Art & Design      June 8, 2018
# 4           Everyone    Art & Design;Creativity     June 20, 2018
# ...              ...                        ...               ...
# 10836       Everyone                  Education     July 25, 2017
# 10837       Everyone                  Education      July 6, 2018
# 10838       Everyone                    Medical  January 20, 2017
# 10839     Mature 17+          Books & Reference  January 19, 2015
# 10840       Everyone                  Lifestyle     July 25, 2018
#
#               Current Ver         Android Ver
# 0                   1.0.0        4.0.3 and up
# 1                   2.0.0        4.0.3 and up
# 2                   1.2.4        4.0.3 and up
# 3      Varies with device          4.2 and up
# 4                     1.1          4.4 and up
# ...                   ...                 ...
# 10836                1.48          4.1 and up
# 10837                 1.0          4.1 and up
# 10838                 1.0          2.2 and up
# 10839  Varies with device  Varies with device
# 10840  Varies with device  Varies with device
#
# [10840 rows x 13 columns]

# %%
df1['Size'] = df1['Size'].apply(value_to_float)
# Out:
# C:\Users\thenu\AppData\Local\Temp\ipykernel_38468\2484780914.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['Size'] = df1['Size'].apply(value_to_float)

# %%
df1
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                             Parkinson Exercices FR              MEDICAL
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
#        Rating_category Reviews        Size     Installs  Type Price  \
# 0             4.100000     159  19000000.0      10,000+  Free     0
# 1             3.900000     967  14000000.0     500,000+  Free     0
# 2             4.700000   87510   8700000.0   5,000,000+  Free     0
# 3             4.500000  215644  25000000.0  50,000,000+  Free     0
# 4             4.300000     967   2800000.0     100,000+  Free     0
# ...                ...     ...         ...          ...   ...   ...
# 10836         4.500000      38  53000000.0       5,000+  Free     0
# 10837         5.000000       4   3600000.0         100+  Free     0
# 10838         4.191757       3   9500000.0       1,000+  Free     0
# 10839         4.500000     114         NaN       1,000+  Free     0
# 10840         4.500000  398307  19000000.0  10,000,000+  Free     0
#
#       Content Rating                     Genres      Last Updated  \
# 0           Everyone               Art & Design   January 7, 2018
# 1           Everyone  Art & Design;Pretend Play  January 15, 2018
# 2           Everyone               Art & Design    August 1, 2018
# 3               Teen               Art & Design      June 8, 2018
# 4           Everyone    Art & Design;Creativity     June 20, 2018
# ...              ...                        ...               ...
# 10836       Everyone                  Education     July 25, 2017
# 10837       Everyone                  Education      July 6, 2018
# 10838       Everyone                    Medical  January 20, 2017
# 10839     Mature 17+          Books & Reference  January 19, 2015
# 10840       Everyone                  Lifestyle     July 25, 2018
#
#               Current Ver         Android Ver
# 0                   1.0.0        4.0.3 and up
# 1                   2.0.0        4.0.3 and up
# 2                   1.2.4        4.0.3 and up
# 3      Varies with device          4.2 and up
# 4                     1.1          4.4 and up
# ...                   ...                 ...
# 10836                1.48          4.1 and up
# 10837                 1.0          4.1 and up
# 10838                 1.0          2.2 and up
# 10839  Varies with device  Varies with device
# 10840  Varies with device  Varies with device
#
# [10840 rows x 13 columns]

# %%
df1.dtypes
# Out:
# App                 object
# Category            object
# Rating_category    float64
# Reviews             object
# Size                object
# Installs            object
# Type                object
# Price               object
# Content Rating      object
# Genres              object
# Last Updated        object
# Current Ver         object
# Android Ver         object
# dtype: object

# %%
df1
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                             Parkinson Exercices FR              MEDICAL
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
#        Rating_category Reviews                Size     Installs  Type Price  \
# 0             4.100000     159                 19M      10,000+  Free     0
# 1             3.900000     967                 14M     500,000+  Free     0
# 2             4.700000   87510                8.7M   5,000,000+  Free     0
# 3             4.500000  215644                 25M  50,000,000+  Free     0
# 4             4.300000     967                2.8M     100,000+  Free     0
# ...                ...     ...                 ...          ...   ...   ...
# 10836         4.500000      38                 53M       5,000+  Free     0
# 10837         5.000000       4                3.6M         100+  Free     0
# 10838         4.191757       3                9.5M       1,000+  Free     0
# 10839         4.500000     114  Varies with device       1,000+  Free     0
# 10840         4.500000  398307                 19M  10,000,000+  Free     0
#
#       Content Rating                     Genres      Last Updated  \
# 0           Everyone               Art & Design   January 7, 2018
# 1           Everyone  Art & Design;Pretend Play  January 15, 2018
# 2           Everyone               Art & Design    August 1, 2018
# 3               Teen               Art & Design      June 8, 2018
# 4           Everyone    Art & Design;Creativity     June 20, 2018
# ...              ...                        ...               ...
# 10836       Everyone                  Education     July 25, 2017
# 10837       Everyone                  Education      July 6, 2018
# 10838       Everyone                    Medical  January 20, 2017
# 10839     Mature 17+          Books & Reference  January 19, 2015
# 10840       Everyone                  Lifestyle     July 25, 2018
#
#               Current Ver         Android Ver
# 0                   1.0.0        4.0.3 and up
# 1                   2.0.0        4.0.3 and up
# 2                   1.2.4        4.0.3 and up
# 3      Varies with device          4.2 and up
# 4                     1.1          4.4 and up
# ...                   ...                 ...
# 10836                1.48          4.1 and up
# 10837                 1.0          4.1 and up
# 10838                 1.0          2.2 and up
# 10839  Varies with device  Varies with device
# 10840  Varies with device  Varies with device
#
# [10840 rows x 13 columns]

# %%
df.loc[10472]
# Out:
# App               Life Made WI-Fi Touchscreen Photo Frame
# Category                                              1.9
# Rating                                               high
# Reviews                                              3.0M
# Size                                               1,000+
# Installs                                             Free
# Type                                                    0
# Price                                            Everyone
# Content Rating                                        NaN
# Genres                                  February 11, 2018
# Last Updated                                       1.0.19
# Current Ver                                    4.0 and up
# Android Ver                                           NaN
# Name: 10472, dtype: object

# %%
#Check the column 'Installs', handle the unwanted characters and convert the column into suitable datatype

# %%
sized = df1[df1['Size'] != 'Varies with device'].copy()

# %%
plt.figure(figsize=(12,6))
plt.title('Distribution of App Sizes')
sns.distplot(sized['Size'],bins = 30,rug=True)
plt.show()
# Out:
# c:\Users\thenu\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# c:\Users\thenu\anaconda3\lib\site-packages\seaborn\distributions.py:2056: FutureWarning: The `axis` variable is no longer used and will be removed. Instead, assign variables directly to `x` or `y`.
#   warnings.warn(msg, FutureWarning)

# %%
# Check the column 'Installs', handle the unwanted characters and convert the column into suitable da

# %%
df1['Installs']=df1.Installs.astype('object')
# Out:
# <ipython-input-139-b12b3577320f>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['Installs']=df1.Installs.astype('object')

# %%
order = ['0','0+','1+','5+','10+','50+','100+','500+','1,000+','5,000+','10,000+','50,000+','100,000+','500,000+','1,000,000+',
         '5,000,000+','10,000,000+',
         '50,000,000+','100,000,000+','500,000,000+','1,000,000,000+']
sns.set_style('whitegrid')
plt.figure(figsize=(22,8))
plt.title('Number of apps on the basis of Installs')
sns.countplot(x='Installs',data = df,palette='hls',order = order)
plt.xticks(rotation = 90)

plt.show()

# %%
df1.isnull().sum()
# Out:
# App                   0
# Category              0
# Rating_category       0
# Reviews               0
# Size               2011
# Installs              0
# Type                  0
# Price                 0
# Content Rating        0
# Genres                0
# Last Updated          0
# Current Ver           0
# Android Ver           0
# dtype: int64

# %%
df
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                             Parkinson Exercices FR              MEDICAL
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
#       Rating Reviews                Size     Installs  Type Price  \
# 0       high     159                 19M      10,000+  Free     0
# 1       high     967                 14M     500,000+  Free     0
# 2       high   87510                8.7M   5,000,000+  Free     0
# 3       high  215644                 25M  50,000,000+  Free     0
# 4       high     967                2.8M     100,000+  Free     0
# ...      ...     ...                 ...          ...   ...   ...
# 10836   high      38                 53M       5,000+  Free     0
# 10837   high       4                3.6M         100+  Free     0
# 10838    low       3                9.5M       1,000+  Free     0
# 10839   high     114  Varies with device       1,000+  Free     0
# 10840   high  398307                 19M  10,000,000+  Free     0
#
#       Content Rating                     Genres      Last Updated  \
# 0           Everyone               Art & Design   January 7, 2018
# 1           Everyone  Art & Design;Pretend Play  January 15, 2018
# 2           Everyone               Art & Design    August 1, 2018
# 3               Teen               Art & Design      June 8, 2018
# 4           Everyone    Art & Design;Creativity     June 20, 2018
# ...              ...                        ...               ...
# 10836       Everyone                  Education     July 25, 2017
# 10837       Everyone                  Education      July 6, 2018
# 10838       Everyone                    Medical  January 20, 2017
# 10839     Mature 17+          Books & Reference  January 19, 2015
# 10840       Everyone                  Lifestyle     July 25, 2018
#
#               Current Ver         Android Ver
# 0                   1.0.0        4.0.3 and up
# 1                   2.0.0        4.0.3 and up
# 2                   1.2.4        4.0.3 and up
# 3      Varies with device          4.2 and up
# 4                     1.1          4.4 and up
# ...                   ...                 ...
# 10836                1.48          4.1 and up
# 10837                 1.0          4.1 and up
# 10838                 1.0          2.2 and up
# 10839  Varies with device  Varies with device
# 10840  Varies with device  Varies with device
#
# [10841 rows x 13 columns]

# %%
#For the target column 'Rating_category' Replace 'high' as 1 and 'low' as 0.

# %%
df1['Rating_category'] =[j for j in map(lambda x: '1' if x == 'high' else '0',df1['Rating_category'])]
# Out:
# <ipython-input-144-044fefdd311e>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['Rating_category'] =[j for j in map(lambda x: '1' if x == 'high' else '0',df1['Rating_category'])]

# %%
def value_to_plus(x):

    if type(x) == object:
        return x
    if x ==" ":
        return 'none'  
    if '+' in x:
        if len(x) > 0:
            m=x.replace('+', '')
            return m

# %%
df['Installs']=df['Installs'].apply(value_to_plus)

# %%
df1['Installs']=df1['Installs'].apply(value_to_plus)
# Out:
# <ipython-input-147-5afdab576bc7>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['Installs']=df1['Installs'].apply(value_to_plus)

# %%
df1["Size"].fillna(method='ffill',inplace=True)
df1["Installs"].fillna(method='ffill',inplace=True)
# Out:
# c:\Users\thenu\anaconda3\lib\site-packages\pandas\core\series.py:4463: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().fillna(

# %%
df1.isnull().sum()
# Out:
# App                0
# Category           0
# Rating_category    0
# Reviews            0
# Size               0
# Installs           0
# Type               0
# Price              0
# Content Rating     0
# Genres             0
# Last Updated       0
# Current Ver        0
# Android Ver        0
# dtype: int64

# %%
df1.isnull().sum()
# Out:
# App                0
# Category           0
# Rating_category    0
# Reviews            0
# Size               0
# Installs           0
# Type               0
# Price              0
# Content Rating     0
# Genres             0
# Last Updated       0
# Current Ver        0
# Android Ver        0
# dtype: int64

# %%
df1
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                             Parkinson Exercices FR              MEDICAL
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
#       Rating_category  Reviews        Size    Installs  Type Price  \
# 0                   1      159  19000000.0      10,000  Free     0
# 1                   1      967  14000000.0     500,000  Free     0
# 2                   1    87510   8700000.0   5,000,000  Free     0
# 3                   1   215644  25000000.0  50,000,000  Free     0
# 4                   1      967   2800000.0     100,000  Free     0
# ...               ...      ...         ...         ...   ...   ...
# 10836               1       38  53000000.0       5,000  Free     0
# 10837               1        4   3600000.0         100  Free     0
# 10838               1        3   9500000.0       1,000  Free     0
# 10839               1      114   9500000.0       1,000  Free     0
# 10840               1   398307  19000000.0  10,000,000  Free     0
#
#       Content Rating                     Genres      Last Updated  \
# 0           Everyone               Art & Design   January 7, 2018
# 1           Everyone  Art & Design;Pretend Play  January 15, 2018
# 2           Everyone               Art & Design    August 1, 2018
# 3               Teen               Art & Design      June 8, 2018
# 4           Everyone    Art & Design;Creativity     June 20, 2018
# ...              ...                        ...               ...
# 10836       Everyone                  Education     July 25, 2017
# 10837       Everyone                  Education      July 6, 2018
# 10838       Everyone                    Medical  January 20, 2017
# 10839     Mature 17+          Books & Reference  January 19, 2015
# 10840       Everyone                  Lifestyle     July 25, 2018
#
#               Current Ver         Android Ver
# 0                   1.0.0        4.0.3 and up
# 1                   2.0.0        4.0.3 and up
# 2                   1.2.4        4.0.3 and up
# 3      Varies with device          4.2 and up
# 4                     1.1          4.4 and up
# ...                   ...                 ...
# 10836                1.48          4.1 and up
# 10837                 1.0          4.1 and up
# 10838                 1.0          2.2 and up
# 10839  Varies with device  Varies with device
# 10840  Varies with device  Varies with device
#
# [10840 rows x 13 columns]

# %%
 #Encode the categorical columns
# %pip install category_encoders
# Out:
# Requirement already satisfied: category_encoders in c:\users\thenu\anaconda3\lib\site-packages (2.6.0)
# Requirement already satisfied: statsmodels>=0.9.0 in c:\users\thenu\anaconda3\lib\site-packages (from category_encoders) (0.12.2)
# Requirement already satisfied: pandas>=1.0.5 in c:\users\thenu\anaconda3\lib\site-packages (from category_encoders) (1.2.4)
# Requirement already satisfied: patsy>=0.5.1 in c:\users\thenu\anaconda3\lib\site-packages (from category_encoders) (0.5.1)
# Requirement already satisfied: scikit-learn>=0.20.0 in c:\users\thenu\anaconda3\lib\site-packages (from category_encoders) (1.2.1)
# Requirement already satisfied: numpy>=1.14.0 in c:\users\thenu\anaconda3\lib\site-packages (from category_encoders) (1.20.1)
# Requirement already satisfied: scipy>=1.0.0 in c:\users\thenu\anaconda3\lib\site-packages (from category_encoders) (1.6.2)
# Requirement already satisfied: python-dateutil>=2.7.3 in c:\users\thenu\anaconda3\lib\site-packages (from pandas>=1.0.5->category_encoders) (2.8.1)
# Requirement already satisfied: pytz>=2017.3 in c:\users\thenu\anaconda3\lib\site-packages (from pandas>=1.0.5->category_encoders) (2021.1)
# Requirement already satisfied: six in c:\users\thenu\anaconda3\lib\site-packages (from patsy>=0.5.1->category_encoders) (1.15.0)
# Requirement already satisfied: joblib>=1.1.1 in c:\users\thenu\anaconda3\lib\site-packages (from scikit-learn>=0.20.0->category_encoders) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\thenu\anaconda3\lib\site-packages (from scikit-learn>=0.20.0->category_encoders) (2.1.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
from sklearn.preprocessing import LabelEncoder

# %%
X=df1.drop(['Rating_category'],axis=1)
y=df1['Rating_category']

# %%
# Encoding categorical variables using label encoder

## select object datatype variables
object_type_variables = [i for i in df1.columns if df1.dtypes[i] == object]
object_type_variables 


le = LabelEncoder()

def encoder(df1):
    for i in object_type_variables:
        q = le.fit_transform(df1[i].astype(str))  
        df1[i] = q                               
        df1[i] = df1[i].astype(int)
encoder(df1)
# Out:
# <ipython-input-155-c6054414fff1>:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1[i] = q
# <ipython-input-155-c6054414fff1>:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1[i] = df1[i].astype(int)

# %%
X=df1.drop(['Rating_category'],axis=1)
y=df1['Rating_category']

# %%
df1.dtypes
# Out:
# App                  int32
# Category             int32
# Rating_category      int32
# Reviews              int64
# Size               float64
# Installs             int32
# Type                 int32
# Price                int32
# Content Rating       int32
# Genres               int32
# Last Updated         int32
# Current Ver          int32
# Android Ver          int32
# dtype: object

# %%
df1
# Out:
#         App  Category  Rating_category  Reviews        Size  Installs  Type  \
# 0      6962         0                1      159  19000000.0         6     0
# 1      2632         0                1      967  14000000.0        18     0
# 2      8656         0                1    87510   8700000.0        13     0
# 3      7827         0                1   215644  25000000.0        16     0
# 4      7022         0                1      967   2800000.0         9     0
# ...     ...       ...              ...      ...         ...       ...   ...
# 10836  8173        11                1       38  53000000.0        12     0
# 10837  4609        11                1        4   3600000.0         8     0
# 10838  6891        20                1        3   9500000.0         2     0
# 10839  8394         3                1      114   9500000.0         2     0
# 10840  9486        18                1   398307  19000000.0         7     0
#
#        Price  Content Rating  Genres  Last Updated  Current Ver  Android Ver
# 0         91               1       9           560          118           15
# 1         91               1      12           480         1018           15
# 2         91               1       9           115          464           15
# 3         91               4       9           823         2764           18
# 4         91               1      11           755          277           20
# ...      ...             ...     ...           ...          ...          ...
# 10836     91               1      39           644          638           17
# 10837     91               1      39           690          113           17
# 10838     91               1      71           504          113            7
# 10839     91               3      19           495         2764           32
# 10840     91               1      67           645         2764           32
#
# [10840 rows x 13 columns]

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.30, random_state=10)  


## Scaling the data

# %%
from sklearn.preprocessing import StandardScaler
ss = StandardScaler()

# %%
df1
# Out:
#         App  Category  Rating_category  Reviews        Size  Installs  Type  \
# 0      6962         0                1      159  19000000.0         6     0
# 1      2632         0                1      967  14000000.0        18     0
# 2      8656         0                1    87510   8700000.0        13     0
# 3      7827         0                1   215644  25000000.0        16     0
# 4      7022         0                1      967   2800000.0         9     0
# ...     ...       ...              ...      ...         ...       ...   ...
# 10836  8173        11                1       38  53000000.0        12     0
# 10837  4609        11                1        4   3600000.0         8     0
# 10838  6891        20                1        3   9500000.0         2     0
# 10839  8394         3                1      114   9500000.0         2     0
# 10840  9486        18                1   398307  19000000.0         7     0
#
#        Price  Content Rating  Genres  Last Updated  Current Ver  Android Ver
# 0         91               1       9           560          118           15
# 1         91               1      12           480         1018           15
# 2         91               1       9           115          464           15
# 3         91               4       9           823         2764           18
# 4         91               1      11           755          277           20
# ...      ...             ...     ...           ...          ...          ...
# 10836     91               1      39           644          638           17
# 10837     91               1      39           690          113           17
# 10838     91               1      71           504          113            7
# 10839     91               3      19           495         2764           32
# 10840     91               1      67           645         2764           32
#
# [10840 rows x 13 columns]

# %%
X_train.iloc[:,:] = ss.fit_transform(X_train.iloc[:,:])
X_test.iloc[:,:] = ss.transform(X_test.iloc[:,:])
# Out:
# c:\Users\thenu\anaconda3\lib\site-packages\pandas\core\indexing.py:1738: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value[:, i].tolist(), pi)
# c:\Users\thenu\anaconda3\lib\site-packages\pandas\core\indexing.py:1738: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value[:, i].tolist(), pi)

# %%
dt = DecisionTreeRegressor()
dt.fit(X_train,y_train)
y_test_pred = dt.predict(X_test)
y_train_pred = dt.predict(X_train)

# %%
print("Train R2_score",r2_score(y_train,y_train_pred))
print("Test R2_score",r2_score(y_test,y_test_pred))
# Out:
# Train R2_score 1.0
# Test R2_score -0.7766074785229373

# %%
max_depth = [3,5,7]
max_features = [3,5,7]
for i in max_depth:
  for j in max_features:
    dt = DecisionTreeRegressor(max_depth = i, max_features=j)
    dt.fit(X_train,y_train)
    y_test_pred = dt.predict(X_test)
    y_train_pred = dt.predict(X_train)
    print(f"Train R2_score with max_depth = {i}, max_feature = {j}",r2_score(y_train,y_train_pred))
    print(f"Test R2_score with max_depth = {i}, max_feature = {j}",r2_score(y_test,y_test_pred))
    print("-"*20)
# Out:
# Train R2_score with max_depth = 3, max_feature = 3 0.06481257278968511
# Test R2_score with max_depth = 3, max_feature = 3 0.03046808391283895
# --------------------
# Train R2_score with max_depth = 3, max_feature = 5 0.068204644039219
# Test R2_score with max_depth = 3, max_feature = 5 0.035296156576612336
# --------------------
# Train R2_score with max_depth = 3, max_feature = 7 0.06380836701202952
# Test R2_score with max_depth = 3, max_feature = 7 0.03946203076883448
# --------------------
# Train R2_score with max_depth = 5, max_feature = 3 0.09219380407209798
# Test R2_score with max_depth = 5, max_feature = 3 0.04254526341442322
# --------------------
# Train R2_score with max_depth = 5, max_feature = 5 0.09012538405374182
# Test R2_score with max_depth = 5, max_feature = 5 0.012771225190449598
# --------------------
# Train R2_score with max_depth = 5, max_feature = 7 0.10439158059585218
# Test R2_score with max_depth = 5, max_feature = 7 0.00480422157681637
# --------------------
# Train R2_score with max_depth = 7, max_feature = 3 0.12353754767788627
# Test R2_score with max_depth = 7, max_feature = 3 -0.009989558357939021
# --------------------
# Train R2_score with max_depth = 7, max_feature = 5 0.14906663183638358
# Test R2_score with max_depth = 7, max_feature = 5 -0.04344849079102975
# --------------------
# Train R2_score with max_depth = 7, max_feature = 7 0.15541390674487676
# Test R2_score with max_depth = 7, max_feature = 7 -0.03672214215790448
# --------------------

# %%
pd.Series(dt.feature_importances_, index = X_train.columns)
# Out:
# App               0.117945
# Category          0.075951
# Reviews           0.458352
# Size              0.087982
# Installs          0.007341
# Type              0.000000
# Price             0.035306
# Content Rating    0.002725
# Genres            0.005214
# Last Updated      0.128478
# Current Ver       0.064731
# Android Ver       0.015976
# dtype: float64

# %%
# so the best features are  category, Installs and price,last updated

# %%
rf = RandomForestRegressor()
rf.fit(X_train,y_train)
y_test_pred = rf.predict(X_test)
y_train_pred = rf.predict(X_train)

# %%
print("Train R2_score",r2_score(y_train,y_train_pred))
print("Test R2_score",r2_score(y_test,y_test_pred))
# Out:
# Train R2_score 0.8688852605038226
# Test R2_score 0.04286577185378526

# %%
print(rf)
# Out:
# RandomForestRegressor()

# %%
ada = AdaBoostRegressor(base_estimator=dt, random_state=7, learning_rate=0.1)
ada.fit(X_train,y_train)
y_test_pred = ada.predict(X_test)
y_train_pred = ada.predict(X_train)

# %%
print("Train R2_score",r2_score(y_train,y_train_pred))
print("Test R2_score",r2_score(y_test,y_test_pred))
# Out:
# Train R2_score 0.04784210540945544
# Test R2_score -0.11610764871861212

# %%
print(ada)
# Out:
# AdaBoostRegressor(base_estimator=DecisionTreeRegressor(max_depth=7,
#                                                        max_features=7),
#                   learning_rate=0.1, random_state=7)

# %%
sr = StackingRegressor(regressors=[LinearRegression(),DecisionTreeRegressor(max_depth=7),AdaBoostRegressor()],
                       meta_regressor = RandomForestRegressor(n_estimators=30))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-174-9b5d9a1366d6> in <module>
# ----> 1 sr = StackingRegressor(regressors=[LinearRegression(),DecisionTreeRegressor(max_depth=7),AdaBoostRegressor()],
#       2                        meta_regressor = RandomForestRegressor(n_estimators=30))
#       3
#
# c:\Users\thenu\anaconda3\lib\site-packages\sklearn\utils\validation.py in inner_f(*args, **kwargs)
#      61         for name, param in sig.parameters.items():
#      62             if param.kind == Parameter.POSITIONAL_OR_KEYWORD:
# ---> 63                 all_args.append(name)
#      64             elif param.kind == Parameter.KEYWORD_ONLY:
#      65                 kwonly_args.append(name)
#
# TypeError: __init__() got an unexpected keyword argument 'regressors'

# %%
#The accuracy of the data, the outcome of r2 score in train modeling and test modeling is not perfect.Thus we have add proper feature to improve the accuracy of the data(i.e,to identify the rating of the app)
