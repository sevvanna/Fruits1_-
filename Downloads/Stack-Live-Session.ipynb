# %% [markdown]
# |                                     |                                      |
# | ---                                 | ---                                  |
# | <img src="http://drive.google.com/uc?export=view&id=1JzM1Jig5KAOCvU4tIf2t66B3gd1uy1rG" width=200px> |<img src="http://drive.google.com/uc?export=view&id=1kMibD1EUis_6bwFtFIOgvUg22zEdROns" width=200px>|
#
# Proprietary content. © Great Learning. All Rights Reserved. Unauthorized use or distribution prohibited.

# %% [markdown]
# # <font color='blue'> Table Of Contents </font>
#
# ## <font color='blue'> Stacks </font>
#
# ### <font color='blue'> Implementation of Stack
#
# * Using Arrays
# * Using Linked lists
#     * Stack operations </font>
#
# ### <font color='blue'> Applications of Stack
#
# * Method call maintenance in Stack
# * Recursion and Stack usage
# * Permutable Stack porblem </font>
#
#
# ### <font color='blue'> Web browser application using Stack </font>
#
# # <font color='blue'> Source Code
#
# * Linked List Implementation
# * Web Browser Application </font>

# %% [markdown]
# # <font color='blue'> Stacks </font>
#
# A stack is a basic data structure that can be logically thought of as a linear structure represented by a real physical stack or pile, a structure where insertion and deletion of items takes place at one end called top of the stack.
#
#
# The basic implementation of a stack is also called a LIFO (Last In First Out) to demonstrate the way it accesses data, since as we will see there are various variations of stack implementations.
#
# There are basically three operations that can be performed on stacks. These are
#
#     1) inserting an item into a stack (push).
#     2) deleting an item from the stack (pop).
#     3) displaying the contents of the stack (peek or top).
#
# ## <font color='blue'> Implementation of Stacks </font>
#
# As we know based on the memory we can divide our data structure in two types, **static** and **dynamic** data structure.
#
# **Static** data structure come with limited size and resizing the space is an overhead once the program execution starts.
#
# Where as **Dynamic** data structures are the once where memory allocation and deallocation happens dynamically as per the requirement of a program.
#
# <img src="http://drive.google.com/uc?export=view&id=1qlSyqCa_W-2kKW4H2OlQkE2okJBAGFxX" width=1000px>
#
# Lets have a look at the type of implementation we can have for Stack data structure.
#
# A stack of an unlimited capacity is a dynamic data structure, regardless of its implementation.
#
# It could be implemented using a linked list or an array which is re-allocated once its capacity is reached. The size of such a stack changes as you add or remove data.
#
# ### <font color='blue'> Implementation Using Array </font>
#
# * Creating an array S of size N. This means that we can not have more than N elements in array.
# * A variable t will be maintained, to help with the ADTs of stack such as push, pop and peek.
# * t will be initialized with -1.
#
#
# <img src="http://drive.google.com/uc?export=view&id=1jvlygl4Fgd-Qv3DFGLr1-v-Xb7hD8yGZ" width=1000px>

# %% [markdown]
# ### <font color='blue'> Implementation Using Linked List </font>
#
# Lets explore the implementation of stack using linked list. Before we will see the code lets have a look at the properties and some generic variables that need to be there.
#
# As we know that every linked list can have its own head and tail pointers to point the beginning and the end of the linked list respectively.
#
# However for the implementation of stack we do not require tail pointer.
#
# According to stack properties we have access to one variable named as top. This variable will be used to implement the methods in stack class.
#
# Considering this we can design our head and linked list in such a way that insertion and deletion of nodes in stack will happen using head node only.
#
# In this section, we are going to us properties of singly linked list where every node will contain at least two information;
#
#     * Node value
#     * Reference to the next pointer
#
#
# Lets have a look at the <class Node> and the members of it.

# %%
class Node:
    def __init__(self, data):
        self.data = data
        self.next = None

# %% [markdown]
# Here we have declared a class that has two attributes *data* and *next.*
#
# - **\<data\>** holds a values assigned by a user
# - **\<next\>** holds the address / memory reference of the next node
#
# Lets have a look at the implementation of the stack data structure using linked list. In the implementation we will be implementing methods to insert, delete data in the stack.
#
# Insert and delete operations are widely known as push and pop operations.
#
# While inserting and deleting the data elements in stack as mentioned earlier we need to maintain and re-configure the head node after every operation.
#
# Following image will help you in understanding the operation and changes required at node level.
#
# <img src="http://drive.google.com/uc?export=view&id=13eUJp0Jd_ilTdPRz_5-w63wqPHTKLXPz" width=1000px>
#
# Lets have a look at the attached code and an explanation associated with it.

# %%
# This is a Linked list implementation of Stack data structure in genric way. 
# This code conatins basic ADT of stack
    # * Push
    # * Pop 
    # * Peek

class Stack:
    # Only one pointer (top) is currently maintained
    # this variable will point to an elemnt which is inserted at last
    # All the push and pop operation will happen using this variable only
    def __init__(self):
        self.top = None

# %% [markdown]
# ### <font color='blue'>  Push Operation </font>

# %%
    # This method will insert data in the stack. 
    def push(self, data):
        # 1. check the if conditon if stack is empty, 
        if self.top is None:
           # a. Insert the new node and make it top of the stack 
            self.top = Node(data)
        else:
            # b. Create a new node
            # c. assign new_node.next to the the current top
            # d. assign new_node pointer to the top
            # this will ensure that top varaible is always pointing to the newly inserted node
            new_node = Node(data)
            new_node.next = self.top
            self.top = new_node

# %% [markdown]
# ### <font color='blue'> isempty Operation </font>

# %%
    # Checking if Stack is empty
    def isempty(self):
        # 1. If top is None
            #a. Stack is empty 
        if self.top is None:
            return True
        #2. Stack has some element. 
        else:
            return False

# %% [markdown]
# ### <font color='blue'>  Peek Operation </font>

# %%
    def peek(self):
        # 1. Checking if stack is empty
        if self.isempty():
            return False
        # 2. If stack has some data
            #a. Print that by using top 
        else:
            print(self.top.data)
            return True

# %% [markdown]
# ### <font color='blue'> Pop Operation </font>

# %%
    # Method to pop the elements one by one form the stack
    def pop(self):
        #1. Check if stack is empty
        if self.isempty():
            return False
        #2. If the stack has some element then deletion can happen
        # we need to update the top as well 
        else:
            #a. save the top reference in another variable
            #b. Move the top pointer to the next node
            #c. Break the link of the pop_node by setting next to None
            #d. Print the data
            pop_node = self.top
            self.top = self.top.next
            pop_node.next = None
            print(pop_node.data)
            return True

# %% [markdown]
# # <font color='blue'> Applications of Stack  </font>
#
#
# ## <font color='blue'> Method call maintenance in Stack  </font>
#
# In this section we are going to look at one of the application of stacks where we will implement multiple methods in a normal python program and we will analyze how stack is used to maintain those method calls.
#
# ### <font color='blue'> Error trace in Stack  </font>
#
# To make this more intereting we have included a situation where an invalid operation will take place in one of the method and we will be analyzing the error received and how we can associate that with the method calls happened.

# %%
def a(n):
    res = n//0
    return res

def b(m):
    val = m + 10
    return a(val)
    
def drive():
    key = 10
    print(b(key))

if __name__ == "__main__":
    drive()

# %% [markdown]
# ## <font color='blue'> Recursive method calls and Use of Stack </font>
#
# In this section we are going to see how recursion utilizes the stack data structure property and how stack is eseential to implement recursion in any of the programming language.
#
# To understand this more deeply, please have a look at the below attached code and lets analyze it visulally.

# %%
count = 0
    
def b(m):
    global count
    if m<=0:
        return 1
    else:
        val = m + 10
        count += val
        m -= 1
        b(m)
    return count

    
def drive():
    key = 10
    print(b(key))

if __name__ == "__main__":
    drive()
# Out:
# 155

# %% [markdown]
# ## <font color='blue'> Stack Permutation Problem  </font>
#
# Lets discuss another problem statment using Stack. This problem is famously known as Stack permutations problem.
#
# The problem “Stack Permutations (Check if an array is stack permutation of other)” states that you are given two lists a[ ] and b[ ] of size n.
#
# All the elements in the lists should be unique. Write a function to check if the given list b[ ] is the stack permutation of given list a[ ] or not.
#
# Here are the rules that should be follwoed:
#
#   a. Only delete operations on both lists.
#
#   b. Use stack operations such as push and pop data from stack.
#
#   c. Stack and input list must be empty at the end.
#
#
# ### <font color='blue'> Algorithms  </font>
#
# 1. Continuously delete elements from the input list.
# 2. Check if it is deleted element is equal to the top of output list or not,
# 3. if it is not equal to the top of output queue then we will push the element to stack.
# 4. Once we find an element in input list such the top of input list is equal to top of output list,
# 5. Delete a single element from both input and output queues, and compare the top of stack and top of output list.
# 6. If top of both stack and output lists are equal then delete element from both stack and output list. If not equal, go to step 1.
# 6. Repeat 1 to 6 until the input list becomes empty.
# 7. If input list and stack are empty then the input list is permutable to output list.

# %%
class Stack: 
# Implementation of Stack using Arrays
# Initialize the Stack with default capacity or given capacity
    def __init__(self):
        self.objects = []
        self.top = -1

    def size(self):                    #Return the current stack size
        return (self.top + 1)

    def isEmpty(self):                 #Return true iff the stack is empty
        return (self.top < 0)

    def push(self, value):               #Push a new element on the stack
        self.top += 1
        self.objects.append(value)

    def peek(self):                      #Return the top stack element
        if (self.isEmpty()):
            print("Stack is empty.")
            return None
        return self.objects[self.top]

    def pop(self):                      #Pop off the stack element
        if (self.isEmpty()):
            print("Stack is Empty."); 
            return 
        elem  = self.objects.pop()
        self.top = self.top-1           #decrement top 
        return elem

def StackPermut(ip, op, n):
    
    tempStack = Stack()
    while (len(ip) != 0):
        ele = ip[0]
        del ip[0]
        if (ele == op[0]):
            del op[0]
            while ((tempStack.size()) != 0):
    
                if (tempStack.peek() == op[0]):
                    tempStack.pop()
                    del op[0]
                else:
                    break
        else:
            tempStack.push(ele)
    
    return (not len(ip) and not (tempStack.size()))
    
# Driver Code
if __name__ == '__main__':

    # Input Queue
    Input = [1, 2, 3]

    # Output Queue
    output = [2, 1, 3]

    n = 3
    if (StackPermut(Input, output, n)):
        print("Yes")
    else:
        print("Not Possible")
# Out:
# Yes

# %% [markdown]
# # <font color='blue'> Web browser application using Stack </font>
#
# As we know stack has multiple real-time application such as undo-redo operation, maintaining the method call stack, Infix to Postfix conversion etc.
#
# In this section, we are going to implement one such use case and we will try to understand how to the properties of a stack can be leveraged.
#
# ## <font color='blue'> Problem Statement </font>
#
# Lets look at the problem statement in detail and the features we want to have in our application.
#
# Let's assume that a user comes and start looking at particular website. During the session he/she might open other website as well in the same tab or move to different different pages on the same website.
#
# Lets look at the feature that we want in our application
#
# Intended Features:
#
# * Start at the home page of a browser
# * When you go to a new web URL, or hit the Forward button, next page should be opened
# * When you hit Back button, you should go back to the page which was available before the current page
# * When you hit the Home button, home page should appear.
#
# ## <font color='blue'> Approach </font>
#
# We are going to use Stack data structure to implement the feature mentioned above. Based on the added problem above lets look at the design for the solution;
#
#
# - A user will generally start with home page over a tab that is empty.
# - To solve the given problem we need to maintain two stacks, BACK_STACK and FORWARD_STACK, both initially empty
# - When user visits a new web URL, or hit the Forward button, the current_url should be moved to the BACK_STACK that is being maintained.
# - When user hits Back button or call back method, the existing page URL should be moved to the FORWARD_STACK
#
# Below we have a Stack class designed with methods in it that will help us in implementing and designing the problem statement.
#
# Lets have a look at the designed class and its methods below.

# %%
class Stack: 
# Implementation of Stack using Arrays
# Initialize the Stack with default capacity or given capacity
    def __init__(self):
        self.objects = []
        self.top = -1

    def size(self):                    #Return the current stack size
        return (self.top + 1)

    def isEmpty(self):                 #Return true iff the stack is empty
        return (self.top < 0)

    def push(self, value):               #Push a new element on the stack
        self.top += 1
        self.objects.append(value)

    def peek(self):                      #Return the top stack element
        if (self.isEmpty()):
            print("Stack is empty.")
            return None
        return self.objects[self.top]

    def pop(self):                      #Pop off the stack element
        if (self.isEmpty()):
            print("Stack is Empty."); 
            return 
        elem  = self.objects.pop()
        self.top = self.top-1           #decrement top 
        return elem

# %% [markdown]
# ### <font color='blue'> Declaring Variables </font>

# %%
# Stores the current
# visiting page
current_state_url = ""
  
# Creating a stack object to store the forward URL's
forward_stack = Stack()
  
# Creating a stack object to store the backward URL's
backward_stack = Stack()

# %% [markdown]
# ### <font color='blue'> Helper Methods </font>

# %%
# To save the current visited URL in the global variable

def visit_new_url(url):
    global current_state_url
    
    # check if there is no URL being serviced or saved currently by a USER 
    if (current_state_url != ""):
    # Enter the first visited page in the backward Stack
        backward_stack.push(current_state_url)

    # Update the gloabl URL with the provided URL 
    current_state_url = url
    print(backward_stack.peek())

# %% [markdown]
# ### <font color='blue'> Maintaing Forward Stack </font>

# %%
# Changinhg the state of global URL and stack values based on the given command. 
def forward():
    # If current url is the last url
    if ((forward_stack.size() == 0) or (current_state_url == forward_stack.peek())):
        print("Not Available")
        return

    # Otherwise
    else:
    # Push current state to the backward stack
        backward_stack.push(current_state_url)

    # Set current state to top of forward stack
        current_state_url = forward_stack.peek()

    # Remove from forward stack
        forward_stack.pop()

# %% [markdown]
# ### <font color='blue'> Maintaing Backward Stack </font>

# %%
# Changinhg the state of global URL and stack values based on the given command. 

def backward():
  # # If current url is the last url
    if ((backward_stack.size() != 0) or (current_state_url == backward_stack.peek())):
        print("Not Available")
        return

    # Otherwise
    else:
    # Push current state to the backward stack
        forward_stack.push(current_state_url)

        # Set current state to top of backward stack
        current_state_url = backward_stack.peek()

        # Pop it from backward stack
        backward_stack.pop()

# %% [markdown]
# ### <font color='blue'> Example Simulation </font>

# %%
def browser_tab_siumlation():
    # Taking new URL
    url = "https://www.iiitd.ac.in/"

    # Moving to  an new URL
    visit_new_url(url)

    # Print the current URL
    print("Current URL is: " + current_state_url)

    # New current URL
    url = "https://www.mygreatlearning.com/"

    # Visit the current URL
    visit_new_url(url)

    # Print the current URL
    print("Current URL is: " + current_state_url)

    # Moving by clicking on  backward button
    backward()

    # Print the current URL
    print("Exiting URL on page after" + " Backward button: " + current_state_url)

    # Moving by clicking on  forward button
    forward()

    # Print the current URL
    print("Exiting URL on page after" + " Forward button: " + current_state_url)

    # New current URL
    url = "https://olympus.greatlearning.in/"

    # Visit the current URL
    visit_new_url(url)

    # Print the current URL
    print("Current URL is: " + current_state_url)

    # Moving by clicking on  forward button
    forward()

    # Print the current URL
    print("Exiting URL on page after" + " Forward button: " + current_state_url)
    # Moving by clicking on  backward button
    backward()

    # Print the current URL
    print("Exiting URL on page after" + " Backward button: " + current_state_url)

# %%
# Function to simulate process of
# pressing forward & backward button
browser_tab_siumlation()

# %% [markdown]
# # <font color='blue'> Source Code </font>
#
# ## <font color='blue'> Linked List Implementation </font>

# %%
class Node:
    def __init__(self, data):
        self.data = data
        self.next = None

# This is a Linked list implementation of Stack data structure in genric way. 
# This code conatins basic ADT of stack
    # * Push
    # * Pop 
    # * Peek

class Stack:
    # Only one pointer (top) is currently maintained
    # this variable will point to an elemnt which is inserted at last
    # All the push and pop operation will happen using this variable only
    def __init__(self):
        self.top = None

    # This method will insert data in the stack. 
    def push(self, data):
        # 1. check the if conditon if stack is empty, 
        if self.top is None:
           # a. Insert the new node and make it top of the stack 
            self.top = Node(data)
        else:
            # b. Create a new node
            # c. assign new_node.next to the the current top
            # d. assign new_node pointer to the top
            # this will ensure that top varaible is always pointing to the newly inserted node
            new_node = Node(data)
            new_node.next = self.top
            self.top = new_node

    # Checking if Stack is empty
    def isempty(self):
        # 1. If top is None
            #a. Stack is empty 
        if self.top is None:
            return True
        #2. Stack has some element. 
        else:
            return False
    
    def peek(self):
        # 1. Checking if stack is empty
        if self.isempty():
            return False
        # 2. If stack has some data
            #a. Print that by using top 
        else:
            print(self.top.data)
            return True

    # Method to pop the elements one by one form the stack
    def pop(self):
        #1. Check if stack is empty
        if self.isempty():
            return False
        #2. If the stack has some element then deletion can happen
        # we need to update the top as well 
        else:
            #a. save the top reference in another variable
            #b. Move the top pointer to the next node
            #c. Break the link of the pop_node by setting next to None
            #d. Print the data
            pop_node = self.top
            self.top = self.top.next
            pop_node.next = None
            print(pop_node.data)
            return True

# %% [markdown]
# ## <font color='blue'> Web browser application </font>

# %%
class Stack: 
# Implementation of Stack using Arrays
# Initialize the Stack with default capacity or given capacity
    def __init__(self):
        self.objects = []
        self.top = -1

    def size(self):                    #Return the current stack size
        return (self.top + 1)

    def isEmpty(self):                 #Return true iff the stack is empty
        return (self.top < 0)

    def push(self, value):               #Push a new element on the stack
        self.top += 1
        self.objects.append(value)

    def peek(self):                      #Return the top stack element
        if (self.isEmpty()):
            print("Stack is empty.")
            return None
        return self.objects[self.top]

    def pop(self):                      #Pop off the stack element
        if (self.isEmpty()):
            print("Stack is Empty."); 
            return 
        elem  = self.objects.pop()
        self.top = self.top-1           #decrement top 
        return elem


# Stores the current
# visiting page
current_state_url = ""
  
# Creating a stack object to store the forward URL's
forward_stack = Stack()
  
# Creating a stack object to store the backward URL's
backward_stack = Stack()   


# To save the current visited URL in the global variable

def visit_new_url(url):
    global current_state_url
    
    # check if there is no URL being serviced or saved currently by a USER 
    if (current_state_url != ""):
    # Enter the first visited page in the backward Stack
        backward_stack.push(current_state_url)

    # Update the gloabl URL with the provided URL 
    current_state_url = url
    print(backward_stack.peek())



# Changinhg the state of global URL and stack values based on the given command. 
def forward():
    # If current url is the last url
    if ((forward_stack.size() == 0) or (current_state_url == forward_stack.peek())):
        print("Not Available")
        return

    # Otherwise
    else:
    # Push current state to the backward stack
        backward_stack.push(current_state_url)

    # Set current state to top of forward stack
        current_state_url = forward_stack.peek()

    # Remove from forward stack
        forward_stack.pop()



# Changinhg the state of global URL and stack values based on the given command. 

def backward():
  # # If current url is the last url
    if ((backward_stack.size() != 0) or (current_state_url == backward_stack.peek())):
        print("Not Available")
        return

    # Otherwise
    else:
    # Push current state to the backward stack
        forward_stack.push(current_state_url)

        # Set current state to top of backward stack
        current_state_url = backward_stack.peek()

        # Pop it from backward stack
        backward_stack.pop()


def browser_tab_siumlation():
    # Taking new URL
    url = "https://www.iiitd.ac.in/"

    # Moving to  an new URL
    visit_new_url(url)

    # Print the current URL
    print("Current URL is: " + current_state_url)

    # New current URL
    url = "https://www.mygreatlearning.com/"

    # Visit the current URL
    visit_new_url(url)

    # Print the current URL
    print("Current URL is: " + current_state_url)

    # Moving by clicking on  backward button
    backward()

    # Print the current URL
    print("Exiting URL on page after" + " Backward button: " + current_state_url)

    # Moving by clicking on  forward button
    forward()

    # Print the current URL
    print("Exiting URL on page after" + " Forward button: " + current_state_url)

    # New current URL
    url = "https://olympus.greatlearning.in/"

    # Visit the current URL
    visit_new_url(url)

    # Print the current URL
    print("Current URL is: " + current_state_url)

    # Moving by clicking on  forward button
    forward()

    # Print the current URL
    print("Exiting URL on page after" + " Forward button: " + current_state_url)
    # Moving by clicking on  backward button
    backward()

    # Print the current URL
    print("Exiting URL on page after" + " Backward button: " + current_state_url)
    

# Function to simulate process of
# pressing forward & backward button
browser_tab_siumlation()
