# %% [markdown]
# # Table of Content

# %% [markdown]
# - About Dataset
# - Importing Data
# - Data Pre processing :
#     - Dropping unnecessary features
#     - Dealing with Duplicate values
#     - Dealing with Missing data
#     - Converting/Removing Special characters to meaningful data
#     - Categorical data conversion
#     - Normalization
#     - Dealing with Outliers

# %% [markdown]
# # About

# %% [markdown]
# - This Data includes lastest edition FIFA 2019 players attributes like Age, Nationality, Overall, Potential, Club, Value, Wage, Preferred Foot, International Reputation, Weak Foot, Skill Moves, Work Rate, Position, Jersey Number, Joined, Loaned From, Contract Valid Until, Height, Weight, LS, ST, RS, LW, LF, CF, RF, RW, LAM, CAM, RAM, LM, LCM, CM, RCM, RM, LWB, LDM, CDM, RDM, RWB, LB, LCB, CB, RCB, RB, Crossing, Finishing, Heading, Accuracy, ShortPassing, Volleys, Dribbling, Curve, FKAccuracy, LongPassing, BallControl, Acceleration, SprintSpeed, Agility, Reactions, Balance, ShotPower, Jumping, Stamina, Strength, LongShots, Aggression, Interceptions, Positioning, Vision, Penalties, Composure, Marking, StandingTackle, SlidingTackle, GKDiving, GKHandling, GKKicking, GKPositioning, GKReflexes, and Release Clause.
# - FIFA 19 is a football simulation video game developed by EA Vancouver as part of Electronic Arts’ FIFA series.
# - The dataset contains information of all 18207 players from the latest edition FIFA 19. There are 89 attributes including personal information like age, name, nationality, photo, club, wage, etc, and also player skill information like ball control, dribbling, crossing, finishing, GK skills and etc.

# %% [markdown]
# - Data source : https://sofifa.com/?r=190075&set=true
# - Inspired from this dataset: https://www.kaggle.com/thec03u5/fifa-18-demo-player-dataset

# %% [markdown]
# ## 1. Load necessary libraries

# %% [markdown]
# Import the necessary libraries

# %% [markdown]
# ## 2. Import and understand the dataset
#  - Check info
#  - Check a few samples
#  - Check statistical summary

# %% [markdown]
# ## 3. Data Preprocessing

# %% [markdown]
# ### 3.1 Drop unnecessary columns such as Unnamed: 0,ID,Photo,Club Logo,Jersey Number,Flag
# - Try to automate it without providing hardcoded feature names

# %% [markdown]
# ### 3.2 Drop duplicate values if present

# %% [markdown]
# ### 3.3 Check for missing data and impute them using an appropriate method

# %% [markdown]
# ### 3.4 There are certain columns having expressions in it (example:- 'LS', 'ST', 'RS', 'LW', etc.). Convert these string expression values to integers.
# - Write a function to automate it

# %% [markdown]
# ### 3.5 From data we can see that Height and Weight are written with their units. Convert them into meaningful values.

# %% [markdown]
# ### 3.6 Analyse the following two features and replace garbage values with  meaningful data.
#  - 'Body Type'
#  - Preferred Foot'
#  - 'Work Rate'
#  - 'Real Face'
#  - 'Position'

# %% [markdown]
# ### 3.7 Analyse the 'Wage' & 'Value' columns and remove the special characters and make it numerical

# %% [markdown]
# ### 3.8 Perform label encoding on each object dtype column through a function

# %% [markdown]
# #### Check the dtypes of each feature using info() function

# %% [markdown]
# lets check label encoding on a single feature/column

# %% [markdown]
# ### 3.8 Check the outliers and handle them appropriately

# %% [markdown]
# Lets check the data statistics through describe function

# %% [markdown]
# #### Finding outliers through Boxplot

# %% [markdown]
# Lets check outliers for few features

# %% [markdown]
# # Self-work for Home

# %% [markdown]
# ## 4. Data Analysis

# %% [markdown]
# ## Univariate Anaysis

# %% [markdown]
# ### 4.1 Check the total number of clubs present in the data

# %% [markdown]
# ### 4.2 Check distribution of Age

# %% [markdown]
# ### 4.3 Check the distribution of Club

# %% [markdown]
# ### 4.4 Check wages for each club
# - We may need this data further, hence we will create separate dataframe for this

# %% [markdown]
# ### 4.5 Find mean overall value for each club

# %% [markdown]
# ### 4.6 What is the economy for each group of club? (Hint : economy is overall divided by wages)

# %% [markdown]
# ### 4.7  Find Top 10 Economical Clubs

# %% [markdown]
# ## Bivariate Analysis

# %% [markdown]
# ### 4.8 Check the Economy of each club using Barplot of seaborn library

# %% [markdown]
# ### 4.9 What is the relationship between age and individual potential of the player? Create a new DF having these two features

# %% [markdown]
# ## Standardization

# %% [markdown]
# ### 4.10 Normalize the above two columns using Sklearn library's StandardScaler class which uses z-score for standardization

# %% [markdown]
# ### 4.11 Add 'Value' feature to the above created DF performanceDataDf and perform analysis between three columns

# %% [markdown]
# ### 4.12 Which skill sets are helpful in deciding a player's potential? Select as per your understanding

# %% [markdown]
# ### 4.13 How do the traits contribute to the players' potential?

# %% [markdown]
# ### 4.14 Which features directly contribute to the wages of the players?
# (Hint: Use Potential, Overall, Value, Special, International Reputation and Wage features only)

# %% [markdown]
# ### 4.15 What is the age distribution in different clubs? Which club has most players young?

# %% [markdown]
# ## Multivariate Analysis

# %% [markdown]
# ### 4.16 Check correlation of all features using heatmap
# - NOTE : As there are too many features, we can not make observations through this plot

# %% [markdown]
# ### 4.17 Check few features using pairplot from seaborn

# %% [markdown]
# ### 4.18 Check weeight for different Clubs with respect to age using lmplot

# %% [markdown]
# ## Happy Learning :)
